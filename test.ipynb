# %%
import pandas as pd
from collections import namedtuple

# %%
DownloadUrl = namedtuple("DownloadUrl", ["url", "file_path", "n_retry"])

# %%
interval = pd.date_range(start="2022-06-06",end="2022-12-06",
                                freq="M").astype("str").tolist()

# %%
interval
# Out:
# ['2022-06-30',
#  '2022-07-31',
#  '2022-08-31',
#  '2022-09-30',
#  '2022-10-31',
#  '2022-11-30']

# %%
for index in range(1, len(interval)):
    print(interval[index-1] , interval[index])
# Out:
# 2022-06-30 2022-07-31
# 2022-07-31 2022-08-31
# 2022-08-31 2022-09-30
# 2022-09-30 2022-10-31
# 2022-10-31 2022-11-30

# %%
import json

# %%
data = open("complaints-2022-12-08_02_36.json" , "r")
json.load(data)
# Out:
# [{'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '6279439',
#   '_score': None,
#   '_source': {'product': 'Credit reporting, credit repair services, or other personal consumer reports',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2022-12-05T12:00:00-05:00',
#    'issue': "Problem with a credit reporting company's investigation into an existing problem",
#    'sub_product': 'Credit reporting',
#    'zip_code': '30339',
#    'tags': None,
#    'complaint_id': '6279439',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'R & B Corporation of Virginia',
#    'date_received': '2022-12-05T12:00:00-05:00',
#    'state': 'GA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': "Company can't verify or dispute the facts in the complaint",
# ...

# %%
[1,2,3] == [1,2,3]
